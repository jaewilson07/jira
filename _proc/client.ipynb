# %% [raw]
# ---
# output-file: client.html
# title: client
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(ResponseGetData)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/jira/blob/main/jira_library/client.py#L16){target="_blank" style="float:right; font-size:smaller"}
#
# ### ResponseGetData
#
# >      ResponseGetData (status:int, response:str, auth:<built-
# >                       infunctionany>=None, is_success:bool=False)
#
# class for returning data from any jiralibrary route

# %%
ResponseGetData(status = 200, response = 'hello world' )
# Out:
# ResponseGetData(status=200, response='hello world', is_success=True)

# %%
#| echo: false
#| output: asis
show_doc(get_data)
# Out:
# ---
#
# [source](https://github.com/jaewilson07/jira/blob/main/jira_library/client.py#L38){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_data
#
# >      get_data (url:str, method:str, auth:<built-infunctionany>,
# >                headers:dict=None, params:dict=None, debug_api:bool=False,
# >                body=None, session:httpx.AsyncClient=None)
